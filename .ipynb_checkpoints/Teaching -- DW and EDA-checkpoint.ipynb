# %% [markdown]
# # Teaching Analysis Data Wrangling and EDA

# %% [markdown]
# Welcome to a deep-dive of my teaching career at Mt. Scott Learning Center through the lens of student outcomes!

# %%
#Load some premliminary packages

import pandas as pd
import glob

path = '/Users/mattnelson/Desktop/GitHub/Teacher/Grade:Student Info/Mine/'
all_files = glob.glob(path + '2*.csv')
for file in all_files:
    print(file)
# Out:
# /Users/mattnelson/Desktop/GitHub/Teacher/Grade:Student Info/Mine/2021-22 Q2 Nelson.csv
# /Users/mattnelson/Desktop/GitHub/Teacher/Grade:Student Info/Mine/2022-23 Q2 Nelson.csv
# /Users/mattnelson/Desktop/GitHub/Teacher/Grade:Student Info/Mine/2019-20 Q2 Nelson.csv
# /Users/mattnelson/Desktop/GitHub/Teacher/Grade:Student Info/Mine/2020-21 Q2 Nelson.csv
# /Users/mattnelson/Desktop/GitHub/Teacher/Grade:Student Info/Mine/2022-23 Q3 Nelson.csv
# /Users/mattnelson/Desktop/GitHub/Teacher/Grade:Student Info/Mine/2020-21 Q1 Nelson.csv
# /Users/mattnelson/Desktop/GitHub/Teacher/Grade:Student Info/Mine/2019-20 Q1 Nelson.csv
# /Users/mattnelson/Desktop/GitHub/Teacher/Grade:Student Info/Mine/2021-22 Q3 Nelson.csv
# /Users/mattnelson/Desktop/GitHub/Teacher/Grade:Student Info/Mine/2020-21 Q4 Nelson.csv
# /Users/mattnelson/Desktop/GitHub/Teacher/Grade:Student Info/Mine/2021-22 Q4 Nelson.csv
# /Users/mattnelson/Desktop/GitHub/Teacher/Grade:Student Info/Mine/2020-21 Q3 Nelson.csv
# /Users/mattnelson/Desktop/GitHub/Teacher/Grade:Student Info/Mine/2019-20 Q3 Nelson.csv
# /Users/mattnelson/Desktop/GitHub/Teacher/Grade:Student Info/Mine/2022-23 Q1 Nelson.csv
# /Users/mattnelson/Desktop/GitHub/Teacher/Grade:Student Info/Mine/2021-22 Q1 Nelson.csv
# /Users/mattnelson/Desktop/GitHub/Teacher/Grade:Student Info/Mine/2022-23 Q4 Nelson.csv

# %%
#Create a DataFrame from all the quarters of gradebooks
p = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    p.append(df)
    
df = pd.concat(p, axis=0, ignore_index=True)
df
# Out:
#                 Course Title TermCode  Period          Teacher  Abs1  \
# 0                   Advisory       Q2       1  Nelson, Matthew    17
# 1                   Advisory       Q2       1  Nelson, Matthew    11
# 2                   Advisory       Q2       1  Nelson, Matthew    30
# 3                   Advisory       Q2       1  Nelson, Matthew    27
# 4                   Advisory       Q2       1  Nelson, Matthew    30
# ...                      ...      ...     ...              ...   ...
# 1596  EC: Race/Cultural Stud       Q4       8  Nelson, Matthew    20
# 1597  EC: Race/Cultural Stud       Q4       8  Nelson, Matthew    15
# 1598  EC: Race/Cultural Stud       Q4       8  Nelson, Matthew    17
# 1599  EC: Race/Cultural Stud       Q4       8  Nelson, Matthew    16
# 1600  EC: Race/Cultural Stud       Q4       8  Nelson, Matthew     2
#
#       SISNumber Grade Comment1 Section ID
# 0        717118     P      NaN        NaN
# 1        762878     P      NaN        NaN
# 2        677110     P      NaN        NaN
# 3        622562     P      NaN        NaN
# 4        617201     P      NaN        NaN
# ...         ...   ...      ...        ...
# 1596     728288     C      NaN        NaN
# 1597     723954     B      NaN        NaN
# 1598     713632     C      NaN        NaN
# 1599     687288     A      NaN        NaN
# 1600     651461     B      NaN        NaN
#
# [1601 rows x 9 columns]

# %%
df.head()
# Out:
#   Course Title TermCode  Period          Teacher  Abs1  SISNumber Grade  \
# 0     Advisory       Q2       1  Nelson, Matthew    17     717118     P
# 1     Advisory       Q2       1  Nelson, Matthew    11     762878     P
# 2     Advisory       Q2       1  Nelson, Matthew    30     677110     P
# 3     Advisory       Q2       1  Nelson, Matthew    27     622562     P
# 4     Advisory       Q2       1  Nelson, Matthew    30     617201     P
#
#   Comment1 Section ID
# 0      NaN        NaN
# 1      NaN        NaN
# 2      NaN        NaN
# 3      NaN        NaN
# 4      NaN        NaN

# %% [markdown]
# I'm guessing that the Comments and the Section ID columns are unnecessary, so I plan on dropping them, but I'm noticing that there isn't a "School Year" column. That's annoying! I can either reload all the csv's one by one and add the columns, or I can look through the aggregated df and look for the splits in Q2 and then add the corresponding years...but none of them are in order so, this might take some time. I need to find the splits. I know that Adivsory class is always the first period of the quarter...Maybe then I could use the index numbers.

# %%
df.groupby(df["Course Title"]=='Advisory').head(25)
# Out:
#                   Course Title TermCode  Period          Teacher  Abs1  \
# 0                     Advisory       Q2       1  Nelson, Matthew    17
# 1                     Advisory       Q2       1  Nelson, Matthew    11
# 2                     Advisory       Q2       1  Nelson, Matthew    30
# 3                     Advisory       Q2       1  Nelson, Matthew    27
# 4                     Advisory       Q2       1  Nelson, Matthew    30
# 5                     Advisory       Q2       1  Nelson, Matthew     6
# 6                     Advisory       Q2       1  Nelson, Matthew    19
# 7                     Advisory       Q2       1  Nelson, Matthew    25
# 8                     Advisory       Q2       1  Nelson, Matthew    12
# 9                     Advisory       Q2       1  Nelson, Matthew    18
# 10                    Advisory       Q2       1  Nelson, Matthew    28
# 11                    Advisory       Q2       1  Nelson, Matthew     9
# 12                    Advisory       Q2       1  Nelson, Matthew    19
# 13                    Advisory       Q2       1  Nelson, Matthew    13
# 14                    Advisory       Q2       1  Nelson, Matthew    12
# 15                    Advisory       Q2       1  Nelson, Matthew    13
# 16   G: Analytical Geometry Q2       Q2       2  Nelson, Matthew    15
# 17   G: Analytical Geometry Q2       Q2       2  Nelson, Matthew     6
# 18   G: Analytical Geometry Q2       Q2       2  Nelson, Matthew    25
# 19   G: Analytical Geometry Q2       Q2       2  Nelson, Matthew     4
# 20   G: Analytical Geometry Q2       Q2       2  Nelson, Matthew     8
# 21   G: Analytical Geometry Q2       Q2       2  Nelson, Matthew    27
# 22   G: Analytical Geometry Q2       Q2       2  Nelson, Matthew     9
# 23   G: Analytical Geometry Q2       Q2       2  Nelson, Matthew    16
# 24   G: Analytical Geometry Q2       Q2       2  Nelson, Matthew    30
# 25   G: Analytical Geometry Q2       Q2       2  Nelson, Matthew    31
# 26   G: Analytical Geometry Q2       Q2       2  Nelson, Matthew    31
# 27   G: Analytical Geometry Q2       Q2       2  Nelson, Matthew     9
# 28   G: Analytical Geometry Q2       Q2       2  Nelson, Matthew    15
# 29   G: Analytical Geometry Q2       Q2       3  Nelson, Matthew    24
# 30   G: Analytical Geometry Q2       Q2       3  Nelson, Matthew    18
# 31   G: Analytical Geometry Q2       Q2       3  Nelson, Matthew    11
# 32   G: Analytical Geometry Q2       Q2       3  Nelson, Matthew     2
# 33   G: Analytical Geometry Q2       Q2       3  Nelson, Matthew    20
# 34   G: Analytical Geometry Q2       Q2       3  Nelson, Matthew    33
# 35   G: Analytical Geometry Q2       Q2       3  Nelson, Matthew    22
# 36   G: Analytical Geometry Q2       Q2       3  Nelson, Matthew     4
# 37   G: Analytical Geometry Q2       Q2       3  Nelson, Matthew    13
# 38   G: Analytical Geometry Q2       Q2       3  Nelson, Matthew    29
# 39   G: Analytical Geometry Q2       Q2       4  Nelson, Matthew     7
# 40   G: Analytical Geometry Q2       Q2       4  Nelson, Matthew    11
# 105                   Advisory       Q2       1  Nelson, Matthew    25
# 106                   Advisory       Q2       1  Nelson, Matthew    15
# 107                   Advisory       Q2       1  Nelson, Matthew     7
# 108                   Advisory       Q2       1  Nelson, Matthew    26
# 109                   Advisory       Q2       1  Nelson, Matthew    33
# 110                   Advisory       Q2       1  Nelson, Matthew    30
# 111                   Advisory       Q2       1  Nelson, Matthew    39
# 112                   Advisory       Q2       1  Nelson, Matthew     1
# 113                   Advisory       Q2       1  Nelson, Matthew    27
#
#      SISNumber Grade Comment1 Section ID
# 0       717118     P      NaN        NaN
# 1       762878     P      NaN        NaN
# 2       677110     P      NaN        NaN
# 3       622562     P      NaN        NaN
# 4       617201     P      NaN        NaN
# 5       751480     P      NaN        NaN
# 6       816925     P      NaN        NaN
# 7       727705     P      NaN        NaN
# 8       781178     P      NaN        NaN
# 9       626678     P      NaN        NaN
# 10      692407     P      NaN        NaN
# 11      778807     P      NaN        NaN
# 12      660613     P      NaN        NaN
# 13      660430     P      NaN        NaN
# 14      721061     P      NaN        NaN
# 15      823043     P      NaN        NaN
# 16      655849     A      NaN        NaN
# 17      762179     A      NaN        NaN
# 18      773644     C      NaN        NaN
# 19      670923     A      NaN        NaN
# 20      647008     C      NaN        NaN
# 21      656640     B      NaN        NaN
# 22      647010     A      NaN        NaN
# 23      774146     C      NaN        NaN
# 24      768097     C      NaN        NaN
# 25      751284     C      NaN        NaN
# 26      570176     C      NaN        NaN
# 27      716407     B      NaN        NaN
# 28      618716     C      NaN        NaN
# 29      317752     A      NaN        NaN
# 30      658563     D      NaN        NaN
# 31      612191     A      NaN        NaN
# 32      515638     C      NaN        NaN
# 33      811707     A      NaN        NaN
# 34      604338    NG      NaN        NaN
# 35      604839    NG      NaN        NaN
# 36      823318     B      NaN        NaN
# 37      626678     B      NaN        NaN
# 38      649817     A      NaN        NaN
# 39      776797     A      NaN        NaN
# 40      714596     A      NaN        NaN
# 105     717118    NP      NaN        NaN
# 106     712371     P      NaN        NaN
# 107     728189     P      NaN        NaN
# 108     692368     P      NaN        NaN
# 109     800850    NP      NaN        NaN
# 110     816925    NP      NaN        NaN
# 111     728288    NP      NaN        NaN
# 112     778724     P      NaN        NaN
# 113     660613     P      NaN        NaN

# %% [markdown]
# Looks like the first split happens at index 105

# %%
#First need to create the new column

df['SchoolYear'] = 0

# %%
#Now need to add the correct school year to the first 105 rows
df.loc[:104, 'SchoolYear']='2021-2022'

# %%
df.loc[105:199, 'SchoolYear']='2022-2023'

# %%
df.loc[200:332, 'SchoolYear']='2019-2020'

# %%
df.loc[333:430, 'SchoolYear']='2020-2021'

# %%
df.loc[431:526, 'SchoolYear']='2022-2023'

# %%
df.loc[527:635, 'SchoolYear']='2020-2021'

# %%
df.loc[636:761, 'SchoolYear']='2019-2020'

# %%
df.loc[762:858, 'SchoolYear']='2021-2022'

# %%
df.loc[859:964, 'SchoolYear']='2020-2021'

# %%
df.loc[965:1067, 'SchoolYear']='2021-2022'

# %%
df.loc[1068:1179, 'SchoolYear']='2020-2021'

# %%
df.loc[1180:1314, 'SchoolYear']='2019-2020'

# %%
df.loc[1315:1401, 'SchoolYear']='2022-2023'

# %%
df.loc[1402:1503, 'SchoolYear']='2021-2022'

# %%
df.loc[1504:, 'SchoolYear']='2022-2023'

# %%
#Need to check...looking good!
df.head(-10)
# Out:
#                      Course Title TermCode  Period          Teacher  Abs1  \
# 0                        Advisory       Q2       1  Nelson, Matthew    17
# 1                        Advisory       Q2       1  Nelson, Matthew    11
# 2                        Advisory       Q2       1  Nelson, Matthew    30
# 3                        Advisory       Q2       1  Nelson, Matthew    27
# 4                        Advisory       Q2       1  Nelson, Matthew    30
# ...                           ...      ...     ...              ...   ...
# 1586  GV: Race & Cultural Studies       Q4       8  Nelson, Matthew     4
# 1587  GV: Race & Cultural Studies       Q4       8  Nelson, Matthew    14
# 1588  GV: Race & Cultural Studies       Q4       8  Nelson, Matthew    24
# 1589  GV: Race & Cultural Studies       Q4       8  Nelson, Matthew    19
# 1590  GV: Race & Cultural Studies       Q4       8  Nelson, Matthew     6
#
#       SISNumber Grade Comment1 Section ID SchoolYear
# 0        717118     P      NaN        NaN  2021-2022
# 1        762878     P      NaN        NaN  2021-2022
# 2        677110     P      NaN        NaN  2021-2022
# 3        622562     P      NaN        NaN  2021-2022
# 4        617201     P      NaN        NaN  2021-2022
# ...         ...   ...      ...        ...        ...
# 1586     814881     A      NaN        NaN  2022-2023
# 1587     818708     A      NaN        NaN  2022-2023
# 1588     676003     P      NaN        NaN  2022-2023
# 1589     737934     D      NaN        NaN  2022-2023
# 1590     724528     C      NaN        NaN  2022-2023
#
# [1591 rows x 10 columns]

# %%
#defintely want to drop comment1 and section id columns though
df=df.drop(columns=['Comment1', 'Section ID'])

# %%
df.head()
# Out:
#   Course Title TermCode  Period          Teacher  Abs1  SISNumber Grade  \
# 0     Advisory       Q2       1  Nelson, Matthew    17     717118     P
# 1     Advisory       Q2       1  Nelson, Matthew    11     762878     P
# 2     Advisory       Q2       1  Nelson, Matthew    30     677110     P
# 3     Advisory       Q2       1  Nelson, Matthew    27     622562     P
# 4     Advisory       Q2       1  Nelson, Matthew    30     617201     P
#
#   SchoolYear
# 0  2021-2022
# 1  2021-2022
# 2  2021-2022
# 3  2021-2022
# 4  2021-2022

# %% [markdown]
# At this point, all the school years are in the dataframe. Although there shouldn't be any missing data, I want to check. After that, I know eventually I'm going to want do some feature engineering on the Grade column (filter out the letter grades into GPA scale (A=4.0, B=3.0, C=2.0, D=1.0, F/NG/NP = 0) and then one-hot encode whether the student passed or not (P,A-D vs F/NG/NP).
#
# I also want to make a note that at the end of 2019-2020 school year, we didn't finish the whole term. Due to Covid-19, the school was shut down for quarantine during third quarter and all those grades are either (P)ass or (I)ncomple. One more thing to note is that my gradebooks are more nuanced that P,A,B,C,D,F/NG/NP with precentages ranging from 0-100+%. What shows up on the final report cards are the simplified integer:letter grades, but I still am condsidering reloading 15 more csv's with more detailed grades.
#
# Further data that needs to be uploaded and added is racial demographics and zip codes, currently being converted from paper into excel sheets, and also Q1 of 2023-2024 school year gradebooks which haven't been finialized as of this note (10/29/2023).

# %%
#Looking for missing data values

print(df.columns)

for col in df.columns:
    n = df[col].isnull().sum()
    print(col,'has ', n, 'null values.')
# Out:
# Index(['Course Title', 'TermCode', 'Period', 'Teacher', 'Abs1', 'SISNumber',
#        'Grade', 'SchoolYear'],
#       dtype='object')
# Course Title has  0 null values.
# TermCode has  0 null values.
# Period has  0 null values.
# Teacher has  0 null values.
# Abs1 has  0 null values.
# SISNumber has  0 null values.
# Grade has  1 null values.
# SchoolYear has  0 null values.

# %%
null = df[df['Grade'].isnull()==True]

# %%
null.head()
# Out:
#              Course Title TermCode  Period          Teacher  Abs1  SISNumber  \
# 456  LA: Creative Writing       Q3       2  Nelson, Matthew     7     828913
#
#     Grade SchoolYear
# 456   NaN  2022-2023

# %% [markdown]
# This is strange, but I'll go back and see what's going on here.
#
# That student dropped out mid-quarter, so I'm going to drop this row.

# %%
df=df.drop([456])

# %%
#Sanity check
new_null = df[df['Grade'].isnull()==True]
new_null.head()
# Out:
# Empty DataFrame
# Columns: [Course Title, TermCode, Period, Teacher, Abs1, SISNumber, Grade, SchoolYear]
# Index: []

# %% [markdown]
# Getting the grade and attendance data for each quarter wasn't too difficult with the assistence of the school's registrar. They easily created Excel sheets for each quarter for each year, with approval for public use after student names had been deleted. But data for race/ethnicity and zip codes had to be hardcopied for each year. After receiving the reports, I had to manually create my own spreadsheet through a process of filtering an aggregation of students in all my classes reduced to one row per student, then finding each student's race/ethnicity data in one hardcopy, and then finding their zip code in another.
#
# Here is the result.

# %%
rz = pd.read_csv('/Users/mattnelson/Desktop/GitHub/Teacher/Grade:Student Info/Mine/Zip and Race - Sheet1.csv')

# %%
rz
# Out:
#      SIS Number         Race    Zip
# 0        804244     Hispanic  97206
# 1        741902        White  97202
# 2        723625        White  97202
# 3        727843        White  97206
# 4        826730        White  97220
# ..          ...          ...    ...
# 327      712121  Two or More  97206
# 328      560619        White  97266
# 329      689565        White  97266
# 330      531348        White  97213
# 331      642704  Two or More  97202
#
# [332 rows x 3 columns]

# %%
me = pd.merge(df, rz, left_on='SISNumber', right_on='SIS Number').drop('SIS Number', axis=1)
me
# Out:
#                            Course Title TermCode  Period          Teacher  \
# 0                              Advisory       Q2       1  Nelson, Matthew
# 1                               Zines B       Q2       5  Nelson, Matthew
# 2                              Advisory       Q2       1  Nelson, Matthew
# 3             G: Analytical Geometry Q2       Q2       4  Nelson, Matthew
# 4                              Advisory       Q2       1  Nelson, Matthew
# ...                                 ...      ...     ...              ...
# 1595               LA: Creative Writing       Q4       2  Nelson, Matthew
# 1596               LA: Creative Writing       Q4       2  Nelson, Matthew
# 1597  H: Periodic Functions/Matrices Q4       Q4       4  Nelson, Matthew
# 1598  H: Periodic Functions/Matrices Q4       Q4       7  Nelson, Matthew
# 1599             EC: Race/Cultural Stud       Q4       8  Nelson, Matthew
#
#       Abs1  SISNumber Grade SchoolYear  \
# 0       17     717118     P  2021-2022
# 1       16     717118     A  2021-2022
# 2       25     717118    NP  2022-2023
# 3       26     717118     C  2022-2023
# 4       13     717118     P  2019-2020
# ...    ...        ...   ...        ...
# 1595     8     763303     A  2022-2023
# 1596    20     724127     B  2022-2023
# 1597     8     781342     A  2022-2023
# 1598     4     809530     A  2022-2023
# 1599    15     829351     A  2022-2023
#
#                                         Race         Zip
# 0                                      White       97206
# 1                                      White       97206
# 2                                      White       97206
# 3                                      White       97206
# 4                                      White       97206
# ...                                      ...         ...
# 1595                                   White       97266
# 1596                             Two or More  97202-4064
# 1597                                   White       97266
# 1598                  Black/African American       97219
# 1599  Native Hawaiian/Other Pacific Islander       97206
#
# [1600 rows x 10 columns]

# %%
#Now I want to make sure my manually inputed data doesn't have any null values

for col in me.columns:
    n = me[col].isnull().sum()
    print(col,'has ', n, 'null values.')
    
#Success!
# Out:
# Course Title has  0 null values.
# TermCode has  0 null values.
# Period has  0 null values.
# Teacher has  0 null values.
# Abs1 has  0 null values.
# SISNumber has  0 null values.
# Grade has  0 null values.
# SchoolYear has  0 null values.
# Race has  0 null values.
# Zip has  0 null values.

# %%
#I'm too excited to not do some preliminary bar graphs, just for giggles!

import matplotlib.pyplot as plt

race_counts = me.groupby('Race')['Race'].count().sort_values()

# %%
print(race_counts)
# Out:
# Race
# Asian                                      11
# Black/African American                    138
# Hispanic                                  281
# Native Hawaiian/Other Pacific Islander      1
# Two or More                               170
# White                                     999
# Name: Race, dtype: int64

# %%
race_counts.index
# Out:
# Index(['Native Hawaiian/Other Pacific Islander', 'Asian',
#        'Black/African American', 'Two or More', 'Hispanic', 'White'],
#       dtype='object', name='Race')

# %%
plt.style.use('ggplot')

races = race_counts.index
counts = race_counts

fig, ax = plt.subplots(figsize=(10,6))

ax.bar(races, counts)
ax.set_ylabel('Count')
ax.set_title('Total Number of Students Taught by Race')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The caveat of this graph is that many of these students I've had mutliple times. I need to group by Student ID and then race, and then I also need to do this by percentage instead of total.
#
# Let's start with Student IDs

# %%
me.head()
# Out:
#                 Course Title TermCode  Period          Teacher  Abs1  \
# 0                   Advisory       Q2       1  Nelson, Matthew    17
# 1                    Zines B       Q2       5  Nelson, Matthew    16
# 2                   Advisory       Q2       1  Nelson, Matthew    25
# 3  G: Analytical Geometry Q2       Q2       4  Nelson, Matthew    26
# 4                   Advisory       Q2       1  Nelson, Matthew    13
#
#    SISNumber Grade SchoolYear   Race    Zip
# 0     717118     P  2021-2022  White  97206
# 1     717118     A  2021-2022  White  97206
# 2     717118    NP  2022-2023  White  97206
# 3     717118     C  2022-2023  White  97206
# 4     717118     P  2019-2020  White  97206

# %%
me['Race'].unique()
# Out:
# array(['White', 'Black/African American', 'Hispanic', 'Two or More',
#        'Asian', 'Native Hawaiian/Other Pacific Islander'], dtype=object)

# %%
race_counts_by_ID = me.groupby(['SISNumber'])['Race'].count()

# %%
race_counts_by_ID
# Out:
# SISNumber
# 285066    3
# 314608    3
# 317752    5
# 375560    1
# 393609    1
#          ..
# 827528    2
# 827709    1
# 828616    4
# 828864    6
# 829351    1
# Name: Race, Length: 331, dtype: int64

# %%
me.pivot_table(values='SISNumber', index='Race', aggfunc=[count()])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[320], line 1
# ----> 1 me.pivot_table(values='SISNumber', index='Race', aggfunc=[count()])
#
# NameError: name 'count' is not defined

# %%
# Out:
# SISNumber  Race
# 285066     White                                     3
# 314608     White                                     3
# 317752     Hispanic                                  5
# 375560     White                                     1
# 393609     White                                     1
#                                                     ..
# 827528     Black/African American                    2
# 827709     White                                     1
# 828616     White                                     4
# 828864     White                                     6
# 829351     Native Hawaiian/Other Pacific Islander    1
# Name: Race, Length: 331, dtype: int64

# %%
#Creating two DataFrames. One with the target variable being Grade and another being Pass/No Pass. Then 
#engineering some features

# %%
#Time to start looking at some data!
